# %%
import pickle as pkl
import matplotlib.pyplot as plt

fileObject = open('variance_save.pkl', 'rb')
variances = pkl.load(fileObject)
fileObject.close()

x = range(len(variances[0]))

fig, ax = plt.subplots()
ax.plot(x[:50], variances[0][:50])
ax.plot(x[:50], variances[1][:50])

fig.show()
# Out:
# /var/folders/3t/n3880lf51_jfhytm836m83p40000gn/T/ipykernel_75467/300546384.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
